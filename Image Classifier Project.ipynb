# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# import library
import argparse
import os
import torch
import torch.utils
import torch.utils.data
import torch.utils.data.dataloader
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms, models
from torch import nn
import torch.optim as optim
from collections import OrderedDict
from time import time
import json
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\tyenc\AppData\Local\Temp\ipykernel_16316\3418649537.py in <module>
#      16 import json
#      17 from PIL import Image
# ---> 18 import matplotlib.pyplot as plt
#      19 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
path = 'flowers'
train_path = path + '/train'
valid_path = path + '/valid'
test_path = path + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
transforms_train = transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225])
    ])

transform_test = transforms.Compose([
        transforms.Resize(255),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225]
        )
    ])
    
transform_valid = transforms.Compose([
        transforms.Resize(255),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225])
    ])

# TODO: Load the datasets with ImageFolder
train_datasets = datasets.ImageFolder(train_path, transform=transforms_train)
print("====> Train datasets done")
test_datasets = datasets.ImageFolder(test_path, transform=transform_test)
print("====> Test datasets done")
valid_datasets = datasets.ImageFolder(valid_path, transform=transform_valid)
print("====> Valid datasets done")

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_datasets, batch_size=64, shuffle=True)
print("====> Train loader done")
valid_loader = torch.utils.data.DataLoader(valid_datasets, batch_size=64, shuffle=True)
print("====> Valid loader done")
test_loader = torch.utils.data.DataLoader(test_datasets, batch_size=64, shuffle=True)
print("====> Test loader done")
# Out:
# ====> Train datasets done
# ====> Test datasets done
# ====> Valid datasets done
# ====> Train loader done
# ====> Valid loader done
# ====> Test loader done

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
def model_pre_train(arch, hidden_units):
    if arch == 'vgg16':
        print("Model VGG16")
        model = models.vgg16(pretrained=True)
    elif arch == 'densenet121':
        print("Model densenet121")
        model = models.densenet121(pretrained=True)
    else:
        print("Unsupport model")
        return
    for param in model.parameters():
        param.requires_grad = False
    model.classifier = nn.Sequential(OrderedDict([
        ('fc1', nn.Linear(model.classifier[0].in_features, hidden_units)),
        ('relu', nn.ReLU()),
        ('dropout', nn.Dropout(0.2)),
        ('fc2', nn.Linear(hidden_units, 256)),
        ('output', nn.LogSoftmax(dim=1))    
    ]))
    print("=====> Model pretrain ")
    print(model)
    print("===========================")
    return model

# check path exist 
def path_is_exist(path):
    exist = False
    if path == '':
        return False
    if not os.path.exists(path):
        print(f"Path {path} does not exist!")
        return False
    return True

# check computer gpu available or not
def cpu_or_gpu(gpu):
    if gpu and torch.cuda.is_available():
        print(" ======> GPU CUDA activated")
        device = torch.device("cuda")
    else:
        print("====> GPU not found !!!")
        device = torch.device("cpu")
    return device

def parser_arguments():
    parser = argparse.ArgumentParser()
    parser.add_argument('data_dir', type=str, help='Path for data directory')
    parser.add_argument('--arch', type=str, help='Training Model', default='vgg16')
    parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate, default 0.001')
    parser.add_argument('--hidden_units', type=int, default=512, help='Number of hidden units, default 512')
    parser.add_argument('--epochs', type=int, default=15, help='Number of epochs')
    parser.add_argument('--gpu', action='store_true', default='gpu', help='use GPU or CPU for training')
    parser.add_argument('--save_dir', type=str, default = './', help='save directory')

    return parser.parse_args()

# 1.2. Loading data
def loading_data(path='flowers'):
    data_path = path
    train_path = path + '/train'
    valid_path = path + '/valid'
    test_path = path + '/test'

    # TODO: Define your transforms for the training, validation, and testing sets
    transforms_train = transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225])
    ])
    print("====> Transform train done")

    transform_test = transforms.Compose([
        transforms.Resize(255),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225]
        )
    ])
    print("====> Transform test done")
    
    transform_valid = transforms.Compose([
        transforms.Resize(255),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225])
    ])
    print("====> Transform valid done")

    # TODO: Load the datasets with ImageFolder
    train_datasets = datasets.ImageFolder(train_path, transform=transforms_train)
    print("====> Train datasets done")
    test_datasets = datasets.ImageFolder(test_path, transform=transform_test)
    print("====> Test datasets done")
    valid_datasets = datasets.ImageFolder(valid_path, transform=transform_valid)
    print("====> Valid datasets done")

    # TODO: Using the image datasets and the trainforms, define the dataloaders
    train_loader = torch.utils.data.DataLoader(train_datasets, batch_size=64, shuffle=True)
    print("====> Train loader done")
    valid_loader = torch.utils.data.DataLoader(valid_datasets, batch_size=64, shuffle=True)
    print("====> Valid loader done")
    test_loader = torch.utils.data.DataLoader(test_datasets, batch_size=64, shuffle=True)
    print("====> Test loader done")

    return train_datasets, train_loader, valid_loader, test_loader

def main():
    path = "flowers"
    device = cpu_or_gpu("gpu")
    epochs = 3
    hidden_units = 512
    arch = "vgg16"
    learning_rate = 0.001
    steps = 0
    running_loss = 0
    print_every = 10
    criterion = nn.NLLLoss()
    model = model_pre_train(arch=arch, hidden_units=hidden_units)
    model.to(device)
    optimizer = optim.Adam(model.classifier.parameters(), lr=learning_rate)
    train_data, train_loader, valid_loader, test_loader = loading_data(path)

    # 3. Use the trained classifier to predict image content
    for epoch in range(epochs):
        t = time()
        for inputs, labels in train_loader:
            steps+= 1
            # Move input & label tensors to the default device
            inputs, labels = inputs.to(device), labels.to(device)
            # clear gradient
            optimizer.zero_grad()
            print(f" Done clear gradients step: {steps} ")

            # forward pass
            logps = model.forward(inputs)
            print(" Done Move forward")
            loss = criterion(logps, labels)
            # backward pass
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:
                loss_val = 0
                accuracy = 0
                model.eval()
                with torch.no_grad():
                    for inputs, labels in valid_loader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        logps = model.forward(inputs)
                        loss_batch = criterion(logps, labels)
                        loss_val += loss_batch.item()

                        # calculate accuracy
                        ps = torch.exp(logps)
                        top_p, top_class = ps.topk(1, dim=1)
                        equals = top_class == labels.view(*top_class.shape)
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                print(
                    f"======> Epoch {epoch + 1}/{epoch}.. "
                    f"======> Train loss: {running_loss/print_every:.3f}.."
                    f"======> Validation loss: {loss_val/len(valid_loader):.3f}.."
                    f"======> Validation accuracy: {accuracy/len(valid_loader):.3f}"
                    )
                running_loss = 0
                model.train()
        print(f" ========> Elapse time for epoch: { epoch+1, time() - t}")

    print("=============== Finish training ==================================")

if __name__ == '__main__':
    main()
# Out:
# ====> GPU not found !!!
# Model VGG16
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# =====> Model pretrain
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )
# ===========================
# ====> Transform train done
# ====> Transform test done
# ====> Transform valid done
# ====> Train datasets done
# ====> Test datasets done
# ====> Valid datasets done
# ====> Train loader done
# ====> Valid loader done
# ====> Test loader done
#  Done clear gradients step: 1
#  Done Move forward
#  Done clear gradients step: 2
#  Done Move forward
#  Done clear gradients step: 3
#  Done Move forward
#  Done clear gradients step: 4
#  Done Move forward
#  Done clear gradients step: 5
#  Done Move forward
#  Done clear gradients step: 6
#  Done Move forward
#  Done clear gradients step: 7
#  Done Move forward
#  Done clear gradients step: 8
#  Done Move forward
#  Done clear gradients step: 9
#  Done Move forward
#  Done clear gradients step: 10
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 4.752..======> Validation loss: 3.453..======> Validation accuracy: 0.288
#  Done clear gradients step: 11
#  Done Move forward
#  Done clear gradients step: 12
#  Done Move forward
#  Done clear gradients step: 13
#  Done Move forward
#  Done clear gradients step: 14
#  Done Move forward
#  Done clear gradients step: 15
#  Done Move forward
#  Done clear gradients step: 16
#  Done Move forward
#  Done clear gradients step: 17
#  Done Move forward
#  Done clear gradients step: 18
#  Done Move forward
#  Done clear gradients step: 19
#  Done Move forward
#  Done clear gradients step: 20
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 3.444..======> Validation loss: 2.431..======> Validation accuracy: 0.420
#  Done clear gradients step: 21
#  Done Move forward
#  Done clear gradients step: 22
#  Done Move forward
#  Done clear gradients step: 23
#  Done Move forward
#  Done clear gradients step: 24
#  Done Move forward
#  Done clear gradients step: 25
#  Done Move forward
#  Done clear gradients step: 26
#  Done Move forward
#  Done clear gradients step: 27
#  Done Move forward
#  Done clear gradients step: 28
#  Done Move forward
#  Done clear gradients step: 29
#  Done Move forward
#  Done clear gradients step: 30
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 2.616..======> Validation loss: 1.870..======> Validation accuracy: 0.548
#  Done clear gradients step: 31
#  Done Move forward
#  Done clear gradients step: 32
#  Done Move forward
#  Done clear gradients step: 33
#  Done Move forward
#  Done clear gradients step: 34
#  Done Move forward
#  Done clear gradients step: 35
#  Done Move forward
#  Done clear gradients step: 36
#  Done Move forward
#  Done clear gradients step: 37
#  Done Move forward
#  Done clear gradients step: 38
#  Done Move forward
#  Done clear gradients step: 39
#  Done Move forward
#  Done clear gradients step: 40
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 2.200..======> Validation loss: 1.502..======> Validation accuracy: 0.621
#  Done clear gradients step: 41
#  Done Move forward
#  Done clear gradients step: 42
#  Done Move forward
#  Done clear gradients step: 43
#  Done Move forward
#  Done clear gradients step: 44
#  Done Move forward
#  Done clear gradients step: 45
#  Done Move forward
#  Done clear gradients step: 46
#  Done Move forward
#  Done clear gradients step: 47
#  Done Move forward
#  Done clear gradients step: 48
#  Done Move forward
#  Done clear gradients step: 49
#  Done Move forward
#  Done clear gradients step: 50
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 2.072..======> Validation loss: 1.234..======> Validation accuracy: 0.687
#  Done clear gradients step: 51
#  Done Move forward
#  Done clear gradients step: 52
#  Done Move forward
#  Done clear gradients step: 53
#  Done Move forward
#  Done clear gradients step: 54
#  Done Move forward
#  Done clear gradients step: 55
#  Done Move forward
#  Done clear gradients step: 56
#  Done Move forward
#  Done clear gradients step: 57
#  Done Move forward
#  Done clear gradients step: 58
#  Done Move forward
#  Done clear gradients step: 59
#  Done Move forward
#  Done clear gradients step: 60
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 1.811..======> Validation loss: 1.109..======> Validation accuracy: 0.717
#  Done clear gradients step: 61
#  Done Move forward
#  Done clear gradients step: 62
#  Done Move forward
#  Done clear gradients step: 63
#  Done Move forward
#  Done clear gradients step: 64
#  Done Move forward
#  Done clear gradients step: 65
#  Done Move forward
#  Done clear gradients step: 66
#  Done Move forward
#  Done clear gradients step: 67
#  Done Move forward
#  Done clear gradients step: 68
#  Done Move forward
#  Done clear gradients step: 69
#  Done Move forward
#  Done clear gradients step: 70
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 1.719..======> Validation loss: 1.037..======> Validation accuracy: 0.734
#  Done clear gradients step: 71
#  Done Move forward
#  Done clear gradients step: 72
#  Done Move forward
#  Done clear gradients step: 73
#  Done Move forward
#  Done clear gradients step: 74
#  Done Move forward
#  Done clear gradients step: 75
#  Done Move forward
#  Done clear gradients step: 76
#  Done Move forward
#  Done clear gradients step: 77
#  Done Move forward
#  Done clear gradients step: 78
#  Done Move forward
#  Done clear gradients step: 79
#  Done Move forward
#  Done clear gradients step: 80
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 1.686..======> Validation loss: 0.788..======> Validation accuracy: 0.783
#  Done clear gradients step: 81
#  Done Move forward
#  Done clear gradients step: 82
#  Done Move forward
#  Done clear gradients step: 83
#  Done Move forward
#  Done clear gradients step: 84
#  Done Move forward
#  Done clear gradients step: 85
#  Done Move forward
#  Done clear gradients step: 86
#  Done Move forward
#  Done clear gradients step: 87
#  Done Move forward
#  Done clear gradients step: 88
#  Done Move forward
#  Done clear gradients step: 89
#  Done Move forward
#  Done clear gradients step: 90
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 1.706..======> Validation loss: 0.841..======> Validation accuracy: 0.766
#  Done clear gradients step: 91
#  Done Move forward
#  Done clear gradients step: 92
#  Done Move forward
#  Done clear gradients step: 93
#  Done Move forward
#  Done clear gradients step: 94
#  Done Move forward
#  Done clear gradients step: 95
#  Done Move forward
#  Done clear gradients step: 96
#  Done Move forward
#  Done clear gradients step: 97
#  Done Move forward
#  Done clear gradients step: 98
#  Done Move forward
#  Done clear gradients step: 99
#  Done Move forward
#  Done clear gradients step: 100
#  Done Move forward
# ======> Epoch 1/0.. ======> Train loss: 1.400..======> Validation loss: 0.744..======> Validation accuracy: 0.801
#  Done clear gradients step: 101
#  Done Move forward
#  Done clear gradients step: 102
#  Done Move forward
#  Done clear gradients step: 103
#  Done Move forward
#  ========> Elapse time for epoch: (1, 2026.6032299995422)
#  Done clear gradients step: 104
#  Done Move forward
#  Done clear gradients step: 105
#  Done Move forward
#  Done clear gradients step: 106
#  Done Move forward
#  Done clear gradients step: 107
#  Done Move forward
#  Done clear gradients step: 108
#  Done Move forward
#  Done clear gradients step: 109
#  Done Move forward
#  Done clear gradients step: 110
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.337..======> Validation loss: 0.664..======> Validation accuracy: 0.821
#  Done clear gradients step: 111
#  Done Move forward
#  Done clear gradients step: 112
#  Done Move forward
#  Done clear gradients step: 113
#  Done Move forward
#  Done clear gradients step: 114
#  Done Move forward
#  Done clear gradients step: 115
#  Done Move forward
#  Done clear gradients step: 116
#  Done Move forward
#  Done clear gradients step: 117
#  Done Move forward
#  Done clear gradients step: 118
#  Done Move forward
#  Done clear gradients step: 119
#  Done Move forward
#  Done clear gradients step: 120
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.152..======> Validation loss: 0.715..======> Validation accuracy: 0.808
#  Done clear gradients step: 121
#  Done Move forward
#  Done clear gradients step: 122
#  Done Move forward
#  Done clear gradients step: 123
#  Done Move forward
#  Done clear gradients step: 124
#  Done Move forward
#  Done clear gradients step: 125
#  Done Move forward
#  Done clear gradients step: 126
#  Done Move forward
#  Done clear gradients step: 127
#  Done Move forward
#  Done clear gradients step: 128
#  Done Move forward
#  Done clear gradients step: 129
#  Done Move forward
#  Done clear gradients step: 130
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.217..======> Validation loss: 0.643..======> Validation accuracy: 0.830
#  Done clear gradients step: 131
#  Done Move forward
#  Done clear gradients step: 132
#  Done Move forward
#  Done clear gradients step: 133
#  Done Move forward
#  Done clear gradients step: 134
#  Done Move forward
#  Done clear gradients step: 135
#  Done Move forward
#  Done clear gradients step: 136
#  Done Move forward
#  Done clear gradients step: 137
#  Done Move forward
#  Done clear gradients step: 138
#  Done Move forward
#  Done clear gradients step: 139
#  Done Move forward
#  Done clear gradients step: 140
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.134..======> Validation loss: 0.653..======> Validation accuracy: 0.825
#  Done clear gradients step: 141
#  Done Move forward
#  Done clear gradients step: 142
#  Done Move forward
#  Done clear gradients step: 143
#  Done Move forward
#  Done clear gradients step: 144
#  Done Move forward
#  Done clear gradients step: 145
#  Done Move forward
#  Done clear gradients step: 146
#  Done Move forward
#  Done clear gradients step: 147
#  Done Move forward
#  Done clear gradients step: 148
#  Done Move forward
#  Done clear gradients step: 149
#  Done Move forward
#  Done clear gradients step: 150
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.258..======> Validation loss: 0.607..======> Validation accuracy: 0.834
#  Done clear gradients step: 151
#  Done Move forward
#  Done clear gradients step: 152
#  Done Move forward
#  Done clear gradients step: 153
#  Done Move forward
#  Done clear gradients step: 154
#  Done Move forward
#  Done clear gradients step: 155
#  Done Move forward
#  Done clear gradients step: 156
#  Done Move forward
#  Done clear gradients step: 157
#  Done Move forward
#  Done clear gradients step: 158
#  Done Move forward
#  Done clear gradients step: 159
#  Done Move forward
#  Done clear gradients step: 160
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.205..======> Validation loss: 0.557..======> Validation accuracy: 0.853
#  Done clear gradients step: 161
#  Done Move forward
#  Done clear gradients step: 162
#  Done Move forward
#  Done clear gradients step: 163
#  Done Move forward
#  Done clear gradients step: 164
#  Done Move forward
#  Done clear gradients step: 165
#  Done Move forward
#  Done clear gradients step: 166
#  Done Move forward
#  Done clear gradients step: 167
#  Done Move forward
#  Done clear gradients step: 168
#  Done Move forward
#  Done clear gradients step: 169
#  Done Move forward
#  Done clear gradients step: 170
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.111..======> Validation loss: 0.592..======> Validation accuracy: 0.854
#  Done clear gradients step: 171
#  Done Move forward
#  Done clear gradients step: 172
#  Done Move forward
#  Done clear gradients step: 173
#  Done Move forward
#  Done clear gradients step: 174
#  Done Move forward
#  Done clear gradients step: 175
#  Done Move forward
#  Done clear gradients step: 176
#  Done Move forward
#  Done clear gradients step: 177
#  Done Move forward
#  Done clear gradients step: 178
#  Done Move forward
#  Done clear gradients step: 179
#  Done Move forward
#  Done clear gradients step: 180
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 0.973..======> Validation loss: 0.531..======> Validation accuracy: 0.843
#  Done clear gradients step: 181
#  Done Move forward
#  Done clear gradients step: 182
#  Done Move forward
#  Done clear gradients step: 183
#  Done Move forward
#  Done clear gradients step: 184
#  Done Move forward
#  Done clear gradients step: 185
#  Done Move forward
#  Done clear gradients step: 186
#  Done Move forward
#  Done clear gradients step: 187
#  Done Move forward
#  Done clear gradients step: 188
#  Done Move forward
#  Done clear gradients step: 189
#  Done Move forward
#  Done clear gradients step: 190
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.142..======> Validation loss: 0.593..======> Validation accuracy: 0.837
#  Done clear gradients step: 191
#  Done Move forward
#  Done clear gradients step: 192
#  Done Move forward
#  Done clear gradients step: 193
#  Done Move forward
#  Done clear gradients step: 194
#  Done Move forward
#  Done clear gradients step: 195
#  Done Move forward
#  Done clear gradients step: 196
#  Done Move forward
#  Done clear gradients step: 197
#  Done Move forward
#  Done clear gradients step: 198
#  Done Move forward
#  Done clear gradients step: 199
#  Done Move forward
#  Done clear gradients step: 200
#  Done Move forward
# ======> Epoch 2/1.. ======> Train loss: 1.047..======> Validation loss: 0.543..======> Validation accuracy: 0.859
#  Done clear gradients step: 201
#  Done Move forward
#  Done clear gradients step: 202
#  Done Move forward
#  Done clear gradients step: 203
#  Done Move forward
#  Done clear gradients step: 204
#  Done Move forward
#  Done clear gradients step: 205
#  Done Move forward
#  Done clear gradients step: 206
#  Done Move forward
#  ========> Elapse time for epoch: (2, 1999.5789904594421)
#  Done clear gradients step: 207
#  Done Move forward
#  Done clear gradients step: 208
#  Done Move forward
#  Done clear gradients step: 209
#  Done Move forward
#  Done clear gradients step: 210
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.984..======> Validation loss: 0.511..======> Validation accuracy: 0.854
#  Done clear gradients step: 211
#  Done Move forward
#  Done clear gradients step: 212
#  Done Move forward
#  Done clear gradients step: 213
#  Done Move forward
#  Done clear gradients step: 214
#  Done Move forward
#  Done clear gradients step: 215
#  Done Move forward
#  Done clear gradients step: 216
#  Done Move forward
#  Done clear gradients step: 217
#  Done Move forward
#  Done clear gradients step: 218
#  Done Move forward
#  Done clear gradients step: 219
#  Done Move forward
#  Done clear gradients step: 220
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.950..======> Validation loss: 0.485..======> Validation accuracy: 0.859
#  Done clear gradients step: 221
#  Done Move forward
#  Done clear gradients step: 222
#  Done Move forward
#  Done clear gradients step: 223
#  Done Move forward
#  Done clear gradients step: 224
#  Done Move forward
#  Done clear gradients step: 225
#  Done Move forward
#  Done clear gradients step: 226
#  Done Move forward
#  Done clear gradients step: 227
#  Done Move forward
#  Done clear gradients step: 228
#  Done Move forward
#  Done clear gradients step: 229
#  Done Move forward
#  Done clear gradients step: 230
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.942..======> Validation loss: 0.496..======> Validation accuracy: 0.870
#  Done clear gradients step: 231
#  Done Move forward
#  Done clear gradients step: 232
#  Done Move forward
#  Done clear gradients step: 233
#  Done Move forward
#  Done clear gradients step: 234
#  Done Move forward
#  Done clear gradients step: 235
#  Done Move forward
#  Done clear gradients step: 236
#  Done Move forward
#  Done clear gradients step: 237
#  Done Move forward
#  Done clear gradients step: 238
#  Done Move forward
#  Done clear gradients step: 239
#  Done Move forward
#  Done clear gradients step: 240
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.898..======> Validation loss: 0.438..======> Validation accuracy: 0.879
#  Done clear gradients step: 241
#  Done Move forward
#  Done clear gradients step: 242
#  Done Move forward
#  Done clear gradients step: 243
#  Done Move forward
#  Done clear gradients step: 244
#  Done Move forward
#  Done clear gradients step: 245
#  Done Move forward
#  Done clear gradients step: 246
#  Done Move forward
#  Done clear gradients step: 247
#  Done Move forward
#  Done clear gradients step: 248
#  Done Move forward
#  Done clear gradients step: 249
#  Done Move forward
#  Done clear gradients step: 250
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.915..======> Validation loss: 0.457..======> Validation accuracy: 0.864
#  Done clear gradients step: 251
#  Done Move forward
#  Done clear gradients step: 252
#  Done Move forward
#  Done clear gradients step: 253
#  Done Move forward
#  Done clear gradients step: 254
#  Done Move forward
#  Done clear gradients step: 255
#  Done Move forward
#  Done clear gradients step: 256
#  Done Move forward
#  Done clear gradients step: 257
#  Done Move forward
#  Done clear gradients step: 258
#  Done Move forward
#  Done clear gradients step: 259
#  Done Move forward
#  Done clear gradients step: 260
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.876..======> Validation loss: 0.462..======> Validation accuracy: 0.870
#  Done clear gradients step: 261
#  Done Move forward
#  Done clear gradients step: 262
#  Done Move forward
#  Done clear gradients step: 263
#  Done Move forward
#  Done clear gradients step: 264
#  Done Move forward
#  Done clear gradients step: 265
#  Done Move forward
#  Done clear gradients step: 266
#  Done Move forward
#  Done clear gradients step: 267
#  Done Move forward
#  Done clear gradients step: 268
#  Done Move forward
#  Done clear gradients step: 269
#  Done Move forward
#  Done clear gradients step: 270
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.927..======> Validation loss: 0.468..======> Validation accuracy: 0.872
#  Done clear gradients step: 271
#  Done Move forward
#  Done clear gradients step: 272
#  Done Move forward
#  Done clear gradients step: 273
#  Done Move forward
#  Done clear gradients step: 274
#  Done Move forward
#  Done clear gradients step: 275
#  Done Move forward
#  Done clear gradients step: 276
#  Done Move forward
#  Done clear gradients step: 277
#  Done Move forward
#  Done clear gradients step: 278
#  Done Move forward
#  Done clear gradients step: 279
#  Done Move forward
#  Done clear gradients step: 280
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.926..======> Validation loss: 0.433..======> Validation accuracy: 0.881
#  Done clear gradients step: 281
#  Done Move forward
#  Done clear gradients step: 282
#  Done Move forward
#  Done clear gradients step: 283
#  Done Move forward
#  Done clear gradients step: 284
#  Done Move forward
#  Done clear gradients step: 285
#  Done Move forward
#  Done clear gradients step: 286
#  Done Move forward
#  Done clear gradients step: 287
#  Done Move forward
#  Done clear gradients step: 288
#  Done Move forward
#  Done clear gradients step: 289
#  Done Move forward
#  Done clear gradients step: 290
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.948..======> Validation loss: 0.434..======> Validation accuracy: 0.880
#  Done clear gradients step: 291
#  Done Move forward
#  Done clear gradients step: 292
#  Done Move forward
#  Done clear gradients step: 293
#  Done Move forward
#  Done clear gradients step: 294
#  Done Move forward
#  Done clear gradients step: 295
#  Done Move forward
#  Done clear gradients step: 296
#  Done Move forward
#  Done clear gradients step: 297
#  Done Move forward
#  Done clear gradients step: 298
#  Done Move forward
#  Done clear gradients step: 299
#  Done Move forward
#  Done clear gradients step: 300
#  Done Move forward
# ======> Epoch 3/2.. ======> Train loss: 0.965..======> Validation loss: 0.415..======> Validation accuracy: 0.885
#  Done clear gradients step: 301
#  Done Move forward
#  Done clear gradients step: 302
#  Done Move forward
#  Done clear gradients step: 303
#  Done Move forward
#  Done clear gradients step: 304
#  Done Move forward
#  Done clear gradients step: 305
#  Done Move forward
#  Done clear gradients step: 306
#  Done Move forward
#  Done clear gradients step: 307
#  Done Move forward
#  Done clear gradients step: 308
#  Done Move forward
#  Done clear gradients step: 309
#  Done Move forward
#  ========> Elapse time for epoch: (3, 2003.9954340457916)
# =============== Finish training ==================================

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
testloss = 0
accuracy = 0
model = model_pre_train(arch="vgg16", hidden_units=512)
device = cpu_or_gpu("gpu")
model.to(device)
model.eval()
train_data, train_loader, valid_loader, test_loader = loading_data(path)
criterion = nn.NLLLoss()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)

        testloss += batch_loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(" ===> Test Loss: {:.3f}.. ".format(testloss/len(test_loader)),
      " ===> Test Accuracy: {:.3f}..".format(accuracy/len(test_loader)))
# Out:
# Model VGG16
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# =====> Model pretrain
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )
# ===========================
# ====> GPU not found !!!
# ====> Transform train done
# ====> Transform test done
# ====> Transform valid done
# ====> Train datasets done
# ====> Test datasets done
# ====> Valid datasets done
# ====> Train loader done
# ====> Valid loader done
# ====> Test loader done
#  ===> Test Loss: 5.592..   ===> Test Accuracy: 0.004..

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint
save_checkpoint_path = 'checkpoint_path.pth'
model.class_to_idx = train_data.class_to_idx
torch.save(
    {
        'class_to_idx': model.class_to_idx,
        'input_size': 25088,
        'output_size': 102,
        'structure': 'vgg16',
        'learning_rate': 0.001,
        'epochs': 10,
        'state_dict': model.state_dict(),
    }, 
    save_checkpoint_path
)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint_data(path):
    # check path to image is exist
    if not path_is_exist(path):
        return
    checkpoint = torch.load(path)
    if checkpoint['structure'] == 'densenet121':
        model = models.densenet121(pretrained=True)
    elif checkpoint['structure'] == 'vgg16':
        model = models.vgg16(pretrained = True)
    else:
        raise ValueError('Model load arch error.')
    for param in model.parameters():
        param.requires_grad = False

    model.classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(model.classifier[0].in_features, 512)),
                          ('relu', nn.ReLU()),
                          ('d_out1', nn.Dropout(p=0.3)),
                          ('fc2', nn.Linear(512, 256)),
                          ('d_out2', nn.Dropout(p=0.3)),
                          ('relu', nn.ReLU()),
                          ('output', nn.LogSoftmax(dim=1))
                        ]))
    
    print(checkpoint.keys())

    #model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])    
        
    return model

model = load_checkpoint_data('checkpoint_path.pth')
# Out:
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\tyenc\AppData\Roaming\Python\Python37\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# dict_keys(['class_to_idx', 'input_size', 'output_size', 'structure', 'learning_rate', 'epochs', 'state_dict'])

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    picture = Image.open(image)
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])
    picture = transform(picture)
    return picture

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, gpu, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    model.eval()
    img = process_image(image_path)
    device = cpu_or_gpu(gpu)
    img = img.unsqueeze(0).to(device)

    with torch.no_grad():
        pre_probs = model(img)
    output_probs = torch.exp(pre_probs)
    probs, indeces = output_probs.topk(topk)

    return probs, indeces

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
image_path = 'flowers/test/1/image_06743.jpg'
probs, indices = predict(image_path, model, "gpu")
print (probs)
print (indices)
# Out:
# ====> GPU not found !!!
# tensor([[0.0068, 0.0065, 0.0062, 0.0062, 0.0061]])
# tensor([[103, 218,  63, 200,  58]])
